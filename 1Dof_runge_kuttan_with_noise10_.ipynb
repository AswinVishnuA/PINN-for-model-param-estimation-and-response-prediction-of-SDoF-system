# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import RNN, Layer
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow import float32, concat, convert_to_tensor, linalg
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class RungeKuttaIntegratorCell(Layer):
    def __init__(self, m, c, k, dt, initial_state, **kwargs):
        super(RungeKuttaIntegratorCell, self).__init__(**kwargs)
        self.Minv = linalg.inv(np.diag(m))
        self._c   = c
        self.K    = self._getCKmatrix(k)
        self.initial_state = initial_state
        self.state_size    = 2*len(m)
        self.A  = np.array([0., 0.5, 0.5, 1.0], dtype='float32')
        self.B  = np.array([[1/6, 2/6, 2/6, 1/6]], dtype='float32')
        self.dt = dt

    def build(self, input_shape, **kwargs):
        self.kernel = self.add_weight("C", shape = self._c.shape, trainable = True, initializer = lambda shape, dtype: self._c, **kwargs)
        self.built  = True

    def call(self, inputs, states):
        C    = self._getCKmatrix(self.kernel)
        y    = states[0][:,:1]
        ydot = states[0][:,1:]
        print("Shape of the State: ",len(states)," ",len(states[0])," ",len(states[0][0]),"\n")
        print("current C value: ",C)
        print(inputs,"        Shape of the inputs: ",len(inputs),len(inputs[0]))
        
        yddoti = self._fun(self.Minv, self.K, C, inputs, y, ydot)
        yi     = y + self.A[0] * ydot * self.dt
        ydoti  = ydot + self.A[0] * yddoti * self.dt
        fn     = self._fun(self.Minv, self.K, C, inputs, yi, ydoti)
        for j in range(1,4):
            yn    = y + self.A[j] * ydot * self.dt
            ydotn = ydot + self.A[j] * yddoti * self.dt
            ydoti = concat([ydoti, ydotn], axis=0)
            fn    = concat([fn, self._fun(self.Minv, self.K, C, inputs, yn, ydotn)], axis=0)

        y    = y + linalg.matmul(self.B, ydoti) * self.dt
        ydot = ydot + linalg.matmul(self.B, fn) * self.dt
        return y, [concat(([y, ydot]), axis=-1)]

    def _fun(self, Minv, K, C, u, y, ydot):
        return linalg.matmul(u - linalg.matmul(ydot, C, transpose_b=True) - linalg.matmul(y, K, transpose_b=True), Minv, transpose_b=True)
                             
    def _getCKmatrix(self, a):
        return convert_to_tensor([[a[0]]], dtype=float32)

    def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
        return self.initial_state

# %%
a = tf.constant(np.arange(1, 2, dtype=np.int32), shape=[1,1])
print(a)
b = tf.constant(np.arange(5, 6, dtype=np.int32), shape=[1,1])
print(b)
print(linalg.matmul(a,b))
a1=np.arange(1,2,dtype=np.int32).reshape((1,1))
print(a1)
b1=np.arange(5,6,dtype=np.int32).reshape((1,1))
print(b1)
print(tf.constant(a1))
print(tf.constant(np.matmul(a1,b1)))
#print(linalg.inv(np.diag(m)))
# print(linalg.matmul(, C, transpose_b=True))
# Out:
# tf.Tensor([[1]], shape=(1, 1), dtype=int32)
# tf.Tensor([[5]], shape=(1, 1), dtype=int32)
# tf.Tensor([[5]], shape=(1, 1), dtype=int32)
# [[1]]
# [[5]]
# tf.Tensor([[1]], shape=(1, 1), dtype=int32)
# tf.Tensor([[5]], shape=(1, 1), dtype=int32)

# %%
def create_model(m, c, k, dt, initial_state, batch_input_shape, return_sequences = True, unroll = False):
    rkCell = RungeKuttaIntegratorCell(m=m, c=c, k=k, dt=dt, initial_state=initial_state)
    PINN   = RNN(cell=rkCell, batch_input_shape=batch_input_shape, return_sequences=return_sequences, return_state=False, unroll=unroll)
    model  = Sequential()
    model.add(PINN)
   
    model.compile(loss='mse', optimizer=RMSprop(0.01), metrics=['mae'])
    return model

# %%
 # masses, spring coefficients, and damping coefficients
m = np.array([200/386], dtype='float32')
c = np.array([1], dtype='float32') # initial guess
k = np.array([20.4], dtype='float32')

# %%
# data
df = pd.read_csv('/content/drive/MyDrive/Major Project/New/Data/Training Datasets/phy/1dof_newbarks - Sheet1.csv')
t = df[['t']].values
dt=0.02

utrain = df[['u']].values[np.newaxis, :, :]*(200)
ytrain = df[['y']].values[np.newaxis, :, :]*-1
noise_y = (10/100)*np.amax(ytrain)*np.random.normal(0, 1, ytrain.shape)
ytrain=ytrain+noise_y
# print(df.describe)

# %%
np.amax(ytrain)
# Out:
# 6.604279590591058

# %%
print(ytrain.shape,utrain.shape)
plt.figure()
plt.plot( t,utrain[0, :, :]/200, 'r',label='m1')
plt.xlabel('t(sec)')
plt.ylabel('ground accel.(g)')
plt.grid('on')

plt.figure()
plt.plot( t,ytrain[0, :, :], 'b',label='y1')
plt.xlabel('t(sec)')
plt.ylabel('y (in)')
plt.grid('on')
# Out:
# (1, 1560, 1) (1, 1560, 1)

# %%
    # fitting physics-informed neural network
initial_state =np.zeros((1,2 * len(m),), dtype='float32')
model = create_model(m, c, k, dt, initial_state=initial_state, batch_input_shape=utrain.shape)
print(model.summary())
yPred_before = model.predict_on_batch(utrain)[0, :, :]
history = model.fit(utrain, ytrain, epochs=200, steps_per_epoch=1, verbose=1)
yPred   = model.predict_on_batch(utrain)[0, :, :]
# Out:
# Shape of the State:  1   1   2
#
# current C value:  Tensor("rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rnn (RNN)                   (1, 1560, 1)              1
#
# =================================================================
# Total params: 1
# Trainable params: 1
# Non-trainable params: 0
# _________________________________________________________________
# None
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Epoch 1/200
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# 1/1 [==============================] - 3s 3s/step - loss: 1.5018 - mae: 0.8783
# Epoch 2/200
# 1/1 [==============================] - 1s 500ms/step - loss: 1.4842 - mae: 0.8740
# Epoch 3/200
# 1/1 [==============================] - 0s 493ms/step - loss: 1.4706 - mae: 0.8707
# Epoch 4/200
# 1/1 [==============================] - 0s 467ms/step - loss: 1.4586 - mae: 0.8678
# Epoch 5/200
# 1/1 [==============================] - 1s 542ms/step - loss: 1.4474 - mae: 0.8650
# Epoch 6/200
# 1/1 [==============================] - 1s 637ms/step - loss: 1.4368 - mae: 0.8624
# Epoch 7/200
# 1/1 [==============================] - 1s 506ms/step - loss: 1.4265 - mae: 0.8598
# Epoch 8/200
# 1/1 [==============================] - 1s 606ms/step - loss: 1.4164 - mae: 0.8573
# Epoch 9/200
# 1/1 [==============================] - 1s 604ms/step - loss: 1.4064 - mae: 0.8548
# Epoch 10/200
# 1/1 [==============================] - 1s 578ms/step - loss: 1.3965 - mae: 0.8523
# Epoch 11/200
# 1/1 [==============================] - 1s 541ms/step - loss: 1.3865 - mae: 0.8498
# Epoch 12/200
# 1/1 [==============================] - 1s 513ms/step - loss: 1.3765 - mae: 0.8473
# Epoch 13/200
# 1/1 [==============================] - 1s 514ms/step - loss: 1.3665 - mae: 0.8447
# Epoch 14/200
# 1/1 [==============================] - 1s 552ms/step - loss: 1.3563 - mae: 0.8422
# Epoch 15/200
# 1/1 [==============================] - 0s 482ms/step - loss: 1.3461 - mae: 0.8396
# Epoch 16/200
# 1/1 [==============================] - 1s 527ms/step - loss: 1.3357 - mae: 0.8369
# Epoch 17/200
# 1/1 [==============================] - 1s 530ms/step - loss: 1.3251 - mae: 0.8342
# Epoch 18/200
# 1/1 [==============================] - 1s 529ms/step - loss: 1.3143 - mae: 0.8315
# Epoch 19/200
# 1/1 [==============================] - 1s 593ms/step - loss: 1.3034 - mae: 0.8287
# Epoch 20/200
# 1/1 [==============================] - 0s 467ms/step - loss: 1.2922 - mae: 0.8259
# Epoch 21/200
# 1/1 [==============================] - 0s 465ms/step - loss: 1.2808 - mae: 0.8230
# Epoch 22/200
# 1/1 [==============================] - 0s 472ms/step - loss: 1.2692 - mae: 0.8201
# Epoch 23/200
# 1/1 [==============================] - 0s 479ms/step - loss: 1.2573 - mae: 0.8171
# Epoch 24/200
# 1/1 [==============================] - 1s 542ms/step - loss: 1.2452 - mae: 0.8141
# Epoch 25/200
# 1/1 [==============================] - 1s 586ms/step - loss: 1.2327 - mae: 0.8109
# Epoch 26/200
# 1/1 [==============================] - 0s 458ms/step - loss: 1.2200 - mae: 0.8077
# Epoch 27/200
# 1/1 [==============================] - 0s 451ms/step - loss: 1.2070 - mae: 0.8043
# Epoch 28/200
# 1/1 [==============================] - 0s 479ms/step - loss: 1.1936 - mae: 0.8008
# Epoch 29/200
# 1/1 [==============================] - 0s 467ms/step - loss: 1.1799 - mae: 0.7972
# Epoch 30/200
# 1/1 [==============================] - 0s 467ms/step - loss: 1.1658 - mae: 0.7935
# Epoch 31/200
# 1/1 [==============================] - 1s 528ms/step - loss: 1.1513 - mae: 0.7898
# Epoch 32/200
# 1/1 [==============================] - 1s 538ms/step - loss: 1.1365 - mae: 0.7858
# Epoch 33/200
# 1/1 [==============================] - 0s 481ms/step - loss: 1.1212 - mae: 0.7818
# Epoch 34/200
# 1/1 [==============================] - 0s 486ms/step - loss: 1.1056 - mae: 0.7775
# Epoch 35/200
# 1/1 [==============================] - 0s 480ms/step - loss: 1.0895 - mae: 0.7732
# Epoch 36/200
# 1/1 [==============================] - 0s 458ms/step - loss: 1.0729 - mae: 0.7687
# Epoch 37/200
# 1/1 [==============================] - 0s 457ms/step - loss: 1.0559 - mae: 0.7640
# Epoch 38/200
# 1/1 [==============================] - 0s 476ms/step - loss: 1.0383 - mae: 0.7591
# Epoch 39/200
# 1/1 [==============================] - 1s 515ms/step - loss: 1.0203 - mae: 0.7539
# Epoch 40/200
# 1/1 [==============================] - 1s 605ms/step - loss: 1.0018 - mae: 0.7485
# Epoch 41/200
# 1/1 [==============================] - 1s 509ms/step - loss: 0.9827 - mae: 0.7429
# Epoch 42/200
# 1/1 [==============================] - 0s 467ms/step - loss: 0.9630 - mae: 0.7371
# Epoch 43/200
# 1/1 [==============================] - 0s 463ms/step - loss: 0.9428 - mae: 0.7310
# Epoch 44/200
# 1/1 [==============================] - 1s 522ms/step - loss: 0.9220 - mae: 0.7245
# Epoch 45/200
# 1/1 [==============================] - 1s 621ms/step - loss: 0.9007 - mae: 0.7178
# Epoch 46/200
# 1/1 [==============================] - 1s 556ms/step - loss: 0.8787 - mae: 0.7108
# Epoch 47/200
# 1/1 [==============================] - 0s 467ms/step - loss: 0.8561 - mae: 0.7035
# Epoch 48/200
# 1/1 [==============================] - 1s 545ms/step - loss: 0.8329 - mae: 0.6959
# Epoch 49/200
# 1/1 [==============================] - 0s 478ms/step - loss: 0.8092 - mae: 0.6879
# Epoch 50/200
# 1/1 [==============================] - 1s 523ms/step - loss: 0.7848 - mae: 0.6794
# Epoch 51/200
# 1/1 [==============================] - 0s 474ms/step - loss: 0.7599 - mae: 0.6705
# Epoch 52/200
# 1/1 [==============================] - 0s 491ms/step - loss: 0.7344 - mae: 0.6613
# Epoch 53/200
# 1/1 [==============================] - 0s 494ms/step - loss: 0.7085 - mae: 0.6516
# Epoch 54/200
# 1/1 [==============================] - 1s 580ms/step - loss: 0.6822 - mae: 0.6415
# Epoch 55/200
# 1/1 [==============================] - 0s 493ms/step - loss: 0.6556 - mae: 0.6310
# Epoch 56/200
# 1/1 [==============================] - 0s 487ms/step - loss: 0.6287 - mae: 0.6200
# Epoch 57/200
# 1/1 [==============================] - 0s 428ms/step - loss: 0.6018 - mae: 0.6085
# Epoch 58/200
# 1/1 [==============================] - 1s 570ms/step - loss: 0.5749 - mae: 0.5965
# Epoch 59/200
# 1/1 [==============================] - 0s 462ms/step - loss: 0.5485 - mae: 0.5843
# Epoch 60/200
# 1/1 [==============================] - 1s 584ms/step - loss: 0.5226 - mae: 0.5720
# Epoch 61/200
# 1/1 [==============================] - 1s 597ms/step - loss: 0.4976 - mae: 0.5595
# Epoch 62/200
# 1/1 [==============================] - 1s 500ms/step - loss: 0.4739 - mae: 0.5467
# Epoch 63/200
# 1/1 [==============================] - 1s 572ms/step - loss: 0.4519 - mae: 0.5342
# Epoch 64/200
# 1/1 [==============================] - 1s 502ms/step - loss: 0.4321 - mae: 0.5222
# Epoch 65/200
# 1/1 [==============================] - 1s 526ms/step - loss: 0.4148 - mae: 0.5115
# Epoch 66/200
# 1/1 [==============================] - 1s 516ms/step - loss: 0.4005 - mae: 0.5021
# Epoch 67/200
# 1/1 [==============================] - 1s 529ms/step - loss: 0.3892 - mae: 0.4945
# Epoch 68/200
# 1/1 [==============================] - 1s 544ms/step - loss: 0.3811 - mae: 0.4894
# Epoch 69/200
# 1/1 [==============================] - 0s 488ms/step - loss: 0.3757 - mae: 0.4861
# Epoch 70/200
# 1/1 [==============================] - 1s 589ms/step - loss: 0.3726 - mae: 0.4842
# Epoch 71/200
# 1/1 [==============================] - 1s 586ms/step - loss: 0.3710 - mae: 0.4832
# Epoch 72/200
# 1/1 [==============================] - 0s 455ms/step - loss: 0.3703 - mae: 0.4829
# Epoch 73/200
# 1/1 [==============================] - 0s 476ms/step - loss: 0.3700 - mae: 0.4827
# Epoch 74/200
# 1/1 [==============================] - 0s 489ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 75/200
# 1/1 [==============================] - 1s 598ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 76/200
# 1/1 [==============================] - 0s 462ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 77/200
# 1/1 [==============================] - 0s 458ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 78/200
# 1/1 [==============================] - 0s 487ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 79/200
# 1/1 [==============================] - 1s 557ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 80/200
# 1/1 [==============================] - 1s 609ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 81/200
# 1/1 [==============================] - 1s 608ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 82/200
# 1/1 [==============================] - 1s 569ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 83/200
# 1/1 [==============================] - 1s 527ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 84/200
# 1/1 [==============================] - 0s 492ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 85/200
# 1/1 [==============================] - 0s 495ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 86/200
# 1/1 [==============================] - 0s 482ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 87/200
# 1/1 [==============================] - 0s 472ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 88/200
# 1/1 [==============================] - 1s 514ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 89/200
# 1/1 [==============================] - 0s 478ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 90/200
# 1/1 [==============================] - 0s 495ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 91/200
# 1/1 [==============================] - 0s 462ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 92/200
# 1/1 [==============================] - 1s 506ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 93/200
# 1/1 [==============================] - 1s 545ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 94/200
# 1/1 [==============================] - 0s 476ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 95/200
# 1/1 [==============================] - 0s 500ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 96/200
# 1/1 [==============================] - 1s 506ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 97/200
# 1/1 [==============================] - 1s 536ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 98/200
# 1/1 [==============================] - 1s 529ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 99/200
# 1/1 [==============================] - 0s 484ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 100/200
# 1/1 [==============================] - 1s 548ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 101/200
# 1/1 [==============================] - 0s 476ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 102/200
# 1/1 [==============================] - 0s 484ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 103/200
# 1/1 [==============================] - 1s 538ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 104/200
# 1/1 [==============================] - 0s 493ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 105/200
# 1/1 [==============================] - 0s 469ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 106/200
# 1/1 [==============================] - 0s 498ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 107/200
# 1/1 [==============================] - 0s 477ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 108/200
# 1/1 [==============================] - 1s 548ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 109/200
# 1/1 [==============================] - 1s 516ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 110/200
# 1/1 [==============================] - 1s 538ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 111/200
# 1/1 [==============================] - 0s 480ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 112/200
# 1/1 [==============================] - 0s 479ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 113/200
# 1/1 [==============================] - 0s 480ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 114/200
# 1/1 [==============================] - 1s 510ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 115/200
# 1/1 [==============================] - 1s 522ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 116/200
# 1/1 [==============================] - 0s 485ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 117/200
# 1/1 [==============================] - 0s 494ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 118/200
# 1/1 [==============================] - 0s 478ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 119/200
# 1/1 [==============================] - 1s 533ms/step - loss: 0.3699 - mae: 0.4827
# Epoch 120/200
# 1/1 [==============================] - 1s 502ms/step - loss: 0.3700 - mae: 0.4827
# Epoch 121/200
# 1/1 [==============================] - 1s 565ms/step - loss: 0.3711 - mae: 0.4837
# Epoch 122/200
# 1/1 [==============================] - 0s 462ms/step - loss: 0.3803 - mae: 0.4889
# Epoch 123/200
# 1/1 [==============================] - 0s 466ms/step - loss: 0.3735 - mae: 0.4856
# Epoch 124/200
# 1/1 [==============================] - 1s 530ms/step - loss: 0.3725 - mae: 0.4842
# Epoch 125/200
# 1/1 [==============================] - 1s 504ms/step - loss: 0.3705 - mae: 0.4831
# Epoch 126/200
# 1/1 [==============================] - 0s 499ms/step - loss: 0.3702 - mae: 0.4828
# Epoch 127/200
# 1/1 [==============================] - 0s 471ms/step - loss: 0.3700 - mae: 0.4828
# Epoch 128/200
# 1/1 [==============================] - 0s 486ms/step - loss: 0.3700 - mae: 0.4827
# Epoch 129/200
# 1/1 [==============================] - 1s 520ms/step - loss: 0.3700 - mae: 0.4828
# Epoch 130/200
# 1/1 [==============================] - 0s 452ms/step - loss: 0.3700 - mae: 0.4827
# Epoch 131/200
# 1/1 [==============================] - 1s 510ms/step - loss: 0.3700 - mae: 0.4828
# Epoch 132/200
# 1/1 [==============================] - 1s 536ms/step - loss: 0.3701 - mae: 0.4827
# Epoch 133/200
# 1/1 [==============================] - 0s 495ms/step - loss: 0.3701 - mae: 0.4829
# Epoch 134/200
# 1/1 [==============================] - 0s 471ms/step - loss: 0.3704 - mae: 0.4829
# Epoch 135/200
# 1/1 [==============================] - 0s 459ms/step - loss: 0.3708 - mae: 0.4834
# Epoch 136/200
# 1/1 [==============================] - 0s 486ms/step - loss: 0.3717 - mae: 0.4837
# Epoch 137/200
# 1/1 [==============================] - 0s 468ms/step - loss: 0.3719 - mae: 0.4844
# Epoch 138/200
# 1/1 [==============================] - 1s 513ms/step - loss: 0.3725 - mae: 0.4842
# Epoch 139/200
# 1/1 [==============================] - 0s 473ms/step - loss: 0.3712 - mae: 0.4837
# Epoch 140/200
# 1/1 [==============================] - 1s 538ms/step - loss: 0.3711 - mae: 0.4833
# Epoch 141/200
# 1/1 [==============================] - 0s 479ms/step - loss: 0.3705 - mae: 0.4832
# Epoch 142/200
# 1/1 [==============================] - 0s 488ms/step - loss: 0.3705 - mae: 0.4829
# Epoch 143/200
# 1/1 [==============================] - 0s 456ms/step - loss: 0.3703 - mae: 0.4830
# Epoch 144/200
# 1/1 [==============================] - 0s 475ms/step - loss: 0.3704 - mae: 0.4829
# Epoch 145/200
# 1/1 [==============================] - 0s 459ms/step - loss: 0.3703 - mae: 0.4830
# Epoch 146/200
# 1/1 [==============================] - 0s 486ms/step - loss: 0.3705 - mae: 0.4829
# Epoch 147/200
# 1/1 [==============================] - 0s 466ms/step - loss: 0.3705 - mae: 0.4832
# Epoch 148/200
# 1/1 [==============================] - 0s 498ms/step - loss: 0.3708 - mae: 0.4831
# Epoch 149/200
# 1/1 [==============================] - 1s 591ms/step - loss: 0.3709 - mae: 0.4835
# Epoch 150/200
# 1/1 [==============================] - 0s 464ms/step - loss: 0.3713 - mae: 0.4835
# Epoch 151/200
# 1/1 [==============================] - 0s 488ms/step - loss: 0.3711 - mae: 0.4837
# Epoch 152/200
# 1/1 [==============================] - 1s 540ms/step - loss: 0.3714 - mae: 0.4835
# Epoch 153/200
# 1/1 [==============================] - 1s 595ms/step - loss: 0.3709 - mae: 0.4835
# Epoch 154/200
# 1/1 [==============================] - 1s 582ms/step - loss: 0.3710 - mae: 0.4832
# Epoch 155/200
# 1/1 [==============================] - 0s 470ms/step - loss: 0.3706 - mae: 0.4833
# Epoch 156/200
# 1/1 [==============================] - 1s 596ms/step - loss: 0.3707 - mae: 0.4830
# Epoch 157/200
# 1/1 [==============================] - 0s 476ms/step - loss: 0.3705 - mae: 0.4832
# Epoch 158/200
# 1/1 [==============================] - 1s 526ms/step - loss: 0.3706 - mae: 0.4830
# Epoch 159/200
# 1/1 [==============================] - 0s 478ms/step - loss: 0.3706 - mae: 0.4832
# Epoch 160/200
# 1/1 [==============================] - 0s 493ms/step - loss: 0.3708 - mae: 0.4831
# Epoch 161/200
# 1/1 [==============================] - 0s 497ms/step - loss: 0.3707 - mae: 0.4833
# Epoch 162/200
# 1/1 [==============================] - 0s 496ms/step - loss: 0.3710 - mae: 0.4832
# Epoch 163/200
# 1/1 [==============================] - 0s 490ms/step - loss: 0.3708 - mae: 0.4835
# Epoch 164/200
# 1/1 [==============================] - 1s 554ms/step - loss: 0.3711 - mae: 0.4833
# Epoch 165/200
# 1/1 [==============================] - 1s 509ms/step - loss: 0.3709 - mae: 0.4835
# Epoch 166/200
# 1/1 [==============================] - 1s 573ms/step - loss: 0.3710 - mae: 0.4833
# Epoch 167/200
# 1/1 [==============================] - 1s 550ms/step - loss: 0.3708 - mae: 0.4834
# Epoch 168/200
# 1/1 [==============================] - 1s 637ms/step - loss: 0.3709 - mae: 0.4832
# Epoch 169/200
# 1/1 [==============================] - 1s 519ms/step - loss: 0.3707 - mae: 0.4833
# Epoch 170/200
# 1/1 [==============================] - 0s 495ms/step - loss: 0.3708 - mae: 0.4831
# Epoch 171/200
# 1/1 [==============================] - 0s 491ms/step - loss: 0.3706 - mae: 0.4833
# Epoch 172/200
# 1/1 [==============================] - 0s 482ms/step - loss: 0.3708 - mae: 0.4831
# Epoch 173/200
# 1/1 [==============================] - 0s 486ms/step - loss: 0.3707 - mae: 0.4833
# Epoch 174/200
# 1/1 [==============================] - 1s 510ms/step - loss: 0.3709 - mae: 0.4831
# Epoch 175/200
# 1/1 [==============================] - 1s 541ms/step - loss: 0.3707 - mae: 0.4834
# Epoch 176/200
# 1/1 [==============================] - 1s 528ms/step - loss: 0.3709 - mae: 0.4832
# Epoch 177/200
# 1/1 [==============================] - 0s 489ms/step - loss: 0.3708 - mae: 0.4834
# Epoch 178/200
# 1/1 [==============================] - 0s 478ms/step - loss: 0.3710 - mae: 0.4832
# Epoch 179/200
# 1/1 [==============================] - 0s 474ms/step - loss: 0.3708 - mae: 0.4834
# Epoch 180/200
# 1/1 [==============================] - 0s 480ms/step - loss: 0.3709 - mae: 0.4832
# Epoch 181/200
# 1/1 [==============================] - 1s 573ms/step - loss: 0.3707 - mae: 0.4834
# Epoch 182/200
# 1/1 [==============================] - 1s 552ms/step - loss: 0.3709 - mae: 0.4832
# Epoch 183/200
# 1/1 [==============================] - 1s 522ms/step - loss: 0.3707 - mae: 0.4833
# Epoch 184/200
# 1/1 [==============================] - 1s 541ms/step - loss: 0.3709 - mae: 0.4831
# Epoch 185/200
# 1/1 [==============================] - 0s 492ms/step - loss: 0.3707 - mae: 0.4833
# Epoch 186/200
# 1/1 [==============================] - 1s 534ms/step - loss: 0.3709 - mae: 0.4831
# Epoch 187/200
# 1/1 [==============================] - 0s 453ms/step - loss: 0.3707 - mae: 0.4833
# Epoch 188/200
# 1/1 [==============================] - 0s 458ms/step - loss: 0.3709 - mae: 0.4832
# Epoch 189/200
# 1/1 [==============================] - 0s 497ms/step - loss: 0.3707 - mae: 0.4834
# Epoch 190/200
# 1/1 [==============================] - 1s 529ms/step - loss: 0.3709 - mae: 0.4832
# Epoch 191/200
# 1/1 [==============================] - 1s 509ms/step - loss: 0.3707 - mae: 0.4834
# Epoch 192/200
# 1/1 [==============================] - 1s 562ms/step - loss: 0.3709 - mae: 0.4832
# Epoch 193/200
# 1/1 [==============================] - 0s 468ms/step - loss: 0.3707 - mae: 0.4834
# Epoch 194/200
# 1/1 [==============================] - 0s 490ms/step - loss: 0.3709 - mae: 0.4832
# Epoch 195/200
# 1/1 [==============================] - 0s 464ms/step - loss: 0.3707 - mae: 0.4833
# Epoch 196/200
# 1/1 [==============================] - 1s 503ms/step - loss: 0.3709 - mae: 0.4832
# Epoch 197/200
# 1/1 [==============================] - 0s 480ms/step - loss: 0.3707 - mae: 0.4833
# Epoch 198/200
# 1/1 [==============================] - 1s 541ms/step - loss: 0.3709 - mae: 0.4832
# Epoch 199/200
# 1/1 [==============================] - 0s 464ms/step - loss: 0.3707 - mae: 0.4833
# Epoch 200/200
# 1/1 [==============================] - 0s 488ms/step - loss: 0.3709 - mae: 0.4832

# %%
    # plotting prediction results
plt.plot( t,ytrain[0, :, :], 'r',label='target')
plt.plot( t,yPred_before[:, :], 'gray', label='before training')
plt.plot( t,yPred[:, :], 'b--', label='after training')
plt.xlabel('t (sec)')
plt.ylabel('y (in)')
plt.grid('on')
plt.legend()
plt.show()

# %%
df = pd.read_csv('/content/drive/MyDrive/Major Project/New/Data/Training Datasets/phy/newbarks_u_02 - Sheet1.csv')
t  = df[['t']].values
dt=0.02
xval = df[['u']].values[np.newaxis, :1560, :]*(200)
yval = df[['y']].values[np.newaxis, :1560, :]*-1
noise_y = (10/100)*np.amax(yval)*np.random.normal(0, 1, yval.shape)
yval=yval+noise_y

ypred=model.predict(xval)
model.evaluate(ypred,yval)
# Out:
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# 1/1 [==============================] - 0s 464ms/step - loss: 1.6699 - mae: 1.0816
# [1.669935941696167, 1.0816442966461182]

# %%
plt.figure()
plt.plot( t[:1560],xval[0, :, :]/200, 'r',label='m1')
plt.xlabel('t(sec)')
plt.ylabel('ground accel.(g)')
plt.grid('on')

plt.figure()
plt.plot( t[:1560],yval[0, :, :], 'b',label='y1')
plt.xlabel('t(sec)')
plt.ylabel('y (in)')
plt.grid('on')

# %%
plt.plot(t[:1560], yval[0, :, :], 'r',label='Actual')
plt.plot( t[:1560],ypred[0,:, :], 'b--', label='Predicted')
plt.xlabel('t (sec)')
plt.ylabel('y (in)')
plt.grid('on')
plt.legend()
plt.show()

# %%
print(model.layers[0].get_weights()[0])
# Out:
# [0.1232174]
