# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import RNN, Layer
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow import float32, concat, convert_to_tensor, linalg
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class RungeKuttaIntegratorCell(Layer):
    def __init__(self, m, c, k, dt, initial_state, **kwargs):
        super(RungeKuttaIntegratorCell, self).__init__(**kwargs)
        self.Minv = linalg.inv(np.diag(m))
        self._c   = c
        self.K    = self._getCKmatrix(k)
        self.initial_state = initial_state
        self.state_size    = 2*len(m)
        self.A  = np.array([0., 0.5, 0.5, 1.0], dtype='float32')
        self.B  = np.array([[1/6, 2/6, 2/6, 1/6]], dtype='float32')
        self.dt = dt

    def build(self, input_shape, **kwargs):
        self.kernel = self.add_weight("C", shape = self._c.shape, trainable = True, initializer = lambda shape, dtype: self._c, **kwargs)
        self.built  = True

    def call(self, inputs, states):
        C    = self._getCKmatrix(self.kernel)
        y    = states[0][:,:1]
        ydot = states[0][:,1:]
        print("Shape of the State: ",len(states)," ",len(states[0])," ",len(states[0][0]),"\n")
        print("current C value: ",C)
        print(inputs,"        Shape of the inputs: ",len(inputs),len(inputs[0]))
        
        yddoti = self._fun(self.Minv, self.K, C, inputs, y, ydot)
        yi     = y + self.A[0] * ydot * self.dt
        ydoti  = ydot + self.A[0] * yddoti * self.dt
        fn     = self._fun(self.Minv, self.K, C, inputs, yi, ydoti)
        for j in range(1,4):
            yn    = y + self.A[j] * ydot * self.dt
            ydotn = ydot + self.A[j] * yddoti * self.dt
            ydoti = concat([ydoti, ydotn], axis=0)
            fn    = concat([fn, self._fun(self.Minv, self.K, C, inputs, yn, ydotn)], axis=0)

        y    = y + linalg.matmul(self.B, ydoti) * self.dt
        ydot = ydot + linalg.matmul(self.B, fn) * self.dt
        return y, [concat(([y, ydot]), axis=-1)]

    def _fun(self, Minv, K, C, u, y, ydot):
        return linalg.matmul(u - linalg.matmul(ydot, C, transpose_b=True) - linalg.matmul(y, K, transpose_b=True), Minv, transpose_b=True)
                             
    def _getCKmatrix(self, a):
        return convert_to_tensor([[a[0]]], dtype=float32)

    def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
        return self.initial_state

# %%
a = tf.constant(np.arange(1, 2, dtype=np.int32), shape=[1,1])
print(a)
b = tf.constant(np.arange(5, 6, dtype=np.int32), shape=[1,1])
print(b)
print(linalg.matmul(a,b))
a1=np.arange(1,2,dtype=np.int32).reshape((1,1))
print(a1)
b1=np.arange(5,6,dtype=np.int32).reshape((1,1))
print(b1)
print(tf.constant(a1))
print(tf.constant(np.matmul(a1,b1)))
#print(linalg.inv(np.diag(m)))
# print(linalg.matmul(, C, transpose_b=True))
# Out:
# tf.Tensor([[1]], shape=(1, 1), dtype=int32)
# tf.Tensor([[5]], shape=(1, 1), dtype=int32)
# tf.Tensor([[5]], shape=(1, 1), dtype=int32)
# [[1]]
# [[5]]
# tf.Tensor([[1]], shape=(1, 1), dtype=int32)
# tf.Tensor([[5]], shape=(1, 1), dtype=int32)

# %%
def create_model(m, c, k, dt, initial_state, batch_input_shape, return_sequences = True, unroll = False):
    rkCell = RungeKuttaIntegratorCell(m=m, c=c, k=k, dt=dt, initial_state=initial_state)
    PINN   = RNN(cell=rkCell, batch_input_shape=batch_input_shape, return_sequences=return_sequences, return_state=False, unroll=unroll)
    model  = Sequential()
    model.add(PINN)
   
    model.compile(loss='mse', optimizer=RMSprop(0.01), metrics=['mae'])
    return model

# %%
 # masses, spring coefficients, and damping coefficients
m = np.array([200/386], dtype='float32')
c = np.array([1], dtype='float32') # initial guess
k = np.array([20.4], dtype='float32')

# %%
# data
df = pd.read_csv('/content/drive/MyDrive/Major Project/New/Data/Training Datasets/phy/1dof_newbarks - Sheet1.csv')
t = df[['t']].values
dt=0.02

utrain = df[['u']].values[np.newaxis, :, :]*(200)
ytrain = df[['y']].values[np.newaxis, :, :]*-1
noise_y = (5/100)*np.amax(ytrain)*np.random.normal(0, 1, ytrain.shape)
ytrain=ytrain+noise_y
# print(df.describe)

# %%
np.amax(ytrain)
# Out:
# 6.031140496936477

# %%
print(ytrain.shape,utrain.shape)
plt.figure()
plt.plot( t,utrain[0, :, :]/200, 'r',label='m1')
plt.xlabel('t(sec)')
plt.ylabel('ground accel.(g)')
plt.grid('on')

plt.figure()
plt.plot( t,ytrain[0, :, :], 'b',label='y1')
plt.xlabel('t(sec)')
plt.ylabel('y (in)')
plt.grid('on')
# Out:
# (1, 1560, 1) (1, 1560, 1)

# %%
    # fitting physics-informed neural network
initial_state =np.zeros((1,2 * len(m),), dtype='float32')
model = create_model(m, c, k, dt, initial_state=initial_state, batch_input_shape=utrain.shape)
print(model.summary())
yPred_before = model.predict_on_batch(utrain)[0, :, :]
history = model.fit(utrain, ytrain, epochs=90, steps_per_epoch=1, verbose=1)
yPred   = model.predict_on_batch(utrain)[0, :, :]
# Out:
# Shape of the State:  1   1   2
#
# current C value:  Tensor("rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rnn (RNN)                   (1, 1560, 1)              1
#
# =================================================================
# Total params: 1
# Trainable params: 1
# Non-trainable params: 0
# _________________________________________________________________
# None
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Epoch 1/90
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# 1/1 [==============================] - 3s 3s/step - loss: 1.1774 - mae: 0.7244
# Epoch 2/90
# 1/1 [==============================] - 0s 477ms/step - loss: 1.1603 - mae: 0.7198
# Epoch 3/90
# 1/1 [==============================] - 0s 484ms/step - loss: 1.1470 - mae: 0.7163
# Epoch 4/90
# 1/1 [==============================] - 1s 532ms/step - loss: 1.1353 - mae: 0.7131
# Epoch 5/90
# 1/1 [==============================] - 1s 593ms/step - loss: 1.1245 - mae: 0.7102
# Epoch 6/90
# 1/1 [==============================] - 0s 456ms/step - loss: 1.1142 - mae: 0.7074
# Epoch 7/90
# 1/1 [==============================] - 0s 473ms/step - loss: 1.1042 - mae: 0.7047
# Epoch 8/90
# 1/1 [==============================] - 0s 479ms/step - loss: 1.0944 - mae: 0.7021
# Epoch 9/90
# 1/1 [==============================] - 0s 487ms/step - loss: 1.0847 - mae: 0.6995
# Epoch 10/90
# 1/1 [==============================] - 1s 512ms/step - loss: 1.0751 - mae: 0.6969
# Epoch 11/90
# 1/1 [==============================] - 1s 510ms/step - loss: 1.0655 - mae: 0.6943
# Epoch 12/90
# 1/1 [==============================] - 1s 508ms/step - loss: 1.0559 - mae: 0.6917
# Epoch 13/90
# 1/1 [==============================] - 0s 486ms/step - loss: 1.0462 - mae: 0.6891
# Epoch 14/90
# 1/1 [==============================] - 1s 546ms/step - loss: 1.0364 - mae: 0.6864
# Epoch 15/90
# 1/1 [==============================] - 0s 494ms/step - loss: 1.0265 - mae: 0.6837
# Epoch 16/90
# 1/1 [==============================] - 0s 471ms/step - loss: 1.0165 - mae: 0.6809
# Epoch 17/90
# 1/1 [==============================] - 0s 473ms/step - loss: 1.0063 - mae: 0.6781
# Epoch 18/90
# 1/1 [==============================] - 1s 529ms/step - loss: 0.9960 - mae: 0.6752
# Epoch 19/90
# 1/1 [==============================] - 1s 643ms/step - loss: 0.9854 - mae: 0.6723
# Epoch 20/90
# 1/1 [==============================] - 0s 465ms/step - loss: 0.9747 - mae: 0.6692
# Epoch 21/90
# 1/1 [==============================] - 0s 461ms/step - loss: 0.9638 - mae: 0.6661
# Epoch 22/90
# 1/1 [==============================] - 1s 548ms/step - loss: 0.9527 - mae: 0.6630
# Epoch 23/90
# 1/1 [==============================] - 0s 454ms/step - loss: 0.9413 - mae: 0.6598
# Epoch 24/90
# 1/1 [==============================] - 0s 468ms/step - loss: 0.9296 - mae: 0.6565
# Epoch 25/90
# 1/1 [==============================] - 0s 468ms/step - loss: 0.9178 - mae: 0.6531
# Epoch 26/90
# 1/1 [==============================] - 0s 474ms/step - loss: 0.9056 - mae: 0.6496
# Epoch 27/90
# 1/1 [==============================] - 0s 471ms/step - loss: 0.8931 - mae: 0.6460
# Epoch 28/90
# 1/1 [==============================] - 0s 487ms/step - loss: 0.8804 - mae: 0.6424
# Epoch 29/90
# 1/1 [==============================] - 0s 469ms/step - loss: 0.8673 - mae: 0.6386
# Epoch 30/90
# 1/1 [==============================] - 0s 492ms/step - loss: 0.8539 - mae: 0.6346
# Epoch 31/90
# 1/1 [==============================] - 0s 465ms/step - loss: 0.8402 - mae: 0.6305
# Epoch 32/90
# 1/1 [==============================] - 0s 480ms/step - loss: 0.8261 - mae: 0.6263
# Epoch 33/90
# 1/1 [==============================] - 0s 467ms/step - loss: 0.8117 - mae: 0.6220
# Epoch 34/90
# 1/1 [==============================] - 1s 506ms/step - loss: 0.7968 - mae: 0.6174
# Epoch 35/90
# 1/1 [==============================] - 1s 508ms/step - loss: 0.7816 - mae: 0.6127
# Epoch 36/90
# 1/1 [==============================] - 0s 475ms/step - loss: 0.7659 - mae: 0.6079
# Epoch 37/90
# 1/1 [==============================] - 0s 484ms/step - loss: 0.7499 - mae: 0.6029
# Epoch 38/90
# 1/1 [==============================] - 1s 509ms/step - loss: 0.7334 - mae: 0.5977
# Epoch 39/90
# 1/1 [==============================] - 0s 453ms/step - loss: 0.7164 - mae: 0.5923
# Epoch 40/90
# 1/1 [==============================] - 0s 467ms/step - loss: 0.6990 - mae: 0.5866
# Epoch 41/90
# 1/1 [==============================] - 0s 470ms/step - loss: 0.6811 - mae: 0.5807
# Epoch 42/90
# 1/1 [==============================] - 0s 442ms/step - loss: 0.6627 - mae: 0.5745
# Epoch 43/90
# 1/1 [==============================] - 0s 459ms/step - loss: 0.6438 - mae: 0.5681
# Epoch 44/90
# 1/1 [==============================] - 0s 490ms/step - loss: 0.6244 - mae: 0.5613
# Epoch 45/90
# 1/1 [==============================] - 0s 495ms/step - loss: 0.6045 - mae: 0.5543
# Epoch 46/90
# 1/1 [==============================] - 0s 465ms/step - loss: 0.5840 - mae: 0.5469
# Epoch 47/90
# 1/1 [==============================] - 0s 464ms/step - loss: 0.5631 - mae: 0.5392
# Epoch 48/90
# 1/1 [==============================] - 0s 476ms/step - loss: 0.5416 - mae: 0.5312
# Epoch 49/90
# 1/1 [==============================] - 0s 479ms/step - loss: 0.5196 - mae: 0.5226
# Epoch 50/90
# 1/1 [==============================] - 0s 493ms/step - loss: 0.4971 - mae: 0.5136
# Epoch 51/90
# 1/1 [==============================] - 0s 476ms/step - loss: 0.4741 - mae: 0.5040
# Epoch 52/90
# 1/1 [==============================] - 0s 474ms/step - loss: 0.4507 - mae: 0.4939
# Epoch 53/90
# 1/1 [==============================] - 1s 1s/step - loss: 0.4269 - mae: 0.4832
# Epoch 54/90
# 1/1 [==============================] - 1s 1s/step - loss: 0.4028 - mae: 0.4720
# Epoch 55/90
# 1/1 [==============================] - 1s 506ms/step - loss: 0.3785 - mae: 0.4602
# Epoch 56/90
# 1/1 [==============================] - 1s 1s/step - loss: 0.3540 - mae: 0.4478
# Epoch 57/90
# 1/1 [==============================] - 1s 507ms/step - loss: 0.3295 - mae: 0.4348
# Epoch 58/90
# 1/1 [==============================] - 0s 487ms/step - loss: 0.3052 - mae: 0.4210
# Epoch 59/90
# 1/1 [==============================] - 0s 467ms/step - loss: 0.2812 - mae: 0.4068
# Epoch 60/90
# 1/1 [==============================] - 0s 491ms/step - loss: 0.2579 - mae: 0.3921
# Epoch 61/90
# 1/1 [==============================] - 1s 507ms/step - loss: 0.2354 - mae: 0.3769
# Epoch 62/90
# 1/1 [==============================] - 1s 545ms/step - loss: 0.2142 - mae: 0.3614
# Epoch 63/90
# 1/1 [==============================] - 0s 444ms/step - loss: 0.1946 - mae: 0.3462
# Epoch 64/90
# 1/1 [==============================] - 1s 533ms/step - loss: 0.1770 - mae: 0.3316
# Epoch 65/90
# 1/1 [==============================] - 0s 481ms/step - loss: 0.1617 - mae: 0.3183
# Epoch 66/90
# 1/1 [==============================] - 1s 502ms/step - loss: 0.1491 - mae: 0.3064
# Epoch 67/90
# 1/1 [==============================] - 0s 482ms/step - loss: 0.1392 - mae: 0.2965
# Epoch 68/90
# 1/1 [==============================] - 0s 498ms/step - loss: 0.1321 - mae: 0.2892
# Epoch 69/90
# 1/1 [==============================] - 1s 564ms/step - loss: 0.1274 - mae: 0.2849
# Epoch 70/90
# 1/1 [==============================] - 0s 482ms/step - loss: 0.1247 - mae: 0.2828
# Epoch 71/90
# 1/1 [==============================] - 0s 472ms/step - loss: 0.1233 - mae: 0.2817
# Epoch 72/90
# 1/1 [==============================] - 0s 470ms/step - loss: 0.1226 - mae: 0.2813
# Epoch 73/90
# 1/1 [==============================] - 0s 495ms/step - loss: 0.1224 - mae: 0.2811
# Epoch 74/90
# 1/1 [==============================] - 0s 470ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 75/90
# 1/1 [==============================] - 0s 471ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 76/90
# 1/1 [==============================] - 0s 463ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 77/90
# 1/1 [==============================] - 0s 467ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 78/90
# 1/1 [==============================] - 0s 447ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 79/90
# 1/1 [==============================] - 0s 470ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 80/90
# 1/1 [==============================] - 0s 469ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 81/90
# 1/1 [==============================] - 0s 474ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 82/90
# 1/1 [==============================] - 0s 491ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 83/90
# 1/1 [==============================] - 1s 546ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 84/90
# 1/1 [==============================] - 1s 540ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 85/90
# 1/1 [==============================] - 1s 533ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 86/90
# 1/1 [==============================] - 0s 483ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 87/90
# 1/1 [==============================] - 0s 482ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 88/90
# 1/1 [==============================] - 0s 491ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 89/90
# 1/1 [==============================] - 1s 549ms/step - loss: 0.1223 - mae: 0.2811
# Epoch 90/90
# 1/1 [==============================] - 0s 464ms/step - loss: 0.1223 - mae: 0.2811

# %%
    # plotting prediction results
plt.plot( t,ytrain[0, :, :], 'r',label='target')
plt.plot( t,yPred_before[:, :], 'gray', label='before training')
plt.plot( t,yPred[:, :], 'b--', label='after training')
plt.xlabel('t (sec)')
plt.ylabel('y (in)')
plt.grid('on')
plt.legend()
plt.show()

# %%
df = pd.read_csv('/content/drive/MyDrive/Major Project/New/Data/Training Datasets/phy/newbarks_u_02 - Sheet1.csv')
t  = df[['t']].values
dt=0.02
xval = df[['u']].values[np.newaxis, :1560, :]*(200)
yval = df[['y']].values[np.newaxis, :1560, :]*-1
noise_y = (5/100)*np.amax(yval)*np.random.normal(0, 1, yval.shape)
yval=yval+noise_y

ypred=model.predict(xval)
model.evaluate(ypred,yval)
# Out:
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/strided_slice_2:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential/rnn/while/runge_kutta_integrator_cell/packed:0", shape=(1, 1), dtype=float32)
# Tensor("sequential/rnn/while/TensorArrayV2Read/TensorListGetItem:0", shape=(1, 1), dtype=float32)         Shape of the inputs:  1 1
# 1/1 [==============================] - 1s 504ms/step - loss: 1.5503 - mae: 1.0416
# [1.5502654314041138, 1.0416325330734253]

# %%
plt.figure()
plt.plot( t[:1560],xval[0, :, :]/200, 'r',label='m1')
plt.xlabel('t(sec)')
plt.ylabel('ground accel.(g)')
plt.grid('on')

plt.figure()
plt.plot( t[:1560],yval[0, :, :], 'b',label='y1')
plt.xlabel('t(sec)')
plt.ylabel('y (in)')
plt.grid('on')

# %%
plt.plot(t[:1560], yval[0, :, :], 'r',label='Actual')
plt.plot( t[:1560],ypred[0,:, :], 'b--', label='Predicted')
plt.xlabel('t (sec)')
plt.ylabel('y (in)')
plt.grid('on')
plt.legend()
plt.show()

# %%
print(model.layers[0].get_weights()[0])
# Out:
# [0.1328573]
