# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import RNN, Layer
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow import float32, concat, convert_to_tensor, linalg
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import scipy.io
#dataDir = "/content/drive/MyDrive/Major Project/New/Data/Training Datasets/phy/"
#mat = scipy.io.loadmat(dataDir + 'data_num.mat')
#print(np.array(mat['input_tf']).shape)
#utrain= pd.DataFrame(mat['input_tf'][2])
#print(utrain.describe())
#ytrain= pd.DataFrame(mat['target_X_tf'][2])
#print(ytrain.describe())
#print(utrain.shape," ",ytrain.shape)
#utrain =np.array([utrain[0].values[:,np.newaxis]])*-1

#ytrain = np.array([ytrain[0].values[:,np.newaxis]])
#print(utrain.shape," ",ytrain.shape)
#print(utrain)

# %%
dataDir = "/content/drive/MyDrive/Major Project/New/Data/Training Datasets/aaaa/EL.txt"
U=np.genfromtxt(dataDir,delimiter='',skip_header=1)

print(U.shape)
columns=["id","time","Force","Displacement","Velocity","Acceleration","Spring Force","Damping Force","Inertial Force","Total Accel","Total Inertial","SpringDampRelInert","SpringDampTotalInert"]
df=pd.DataFrame(U,columns=columns)
df.head()
# Out:
# (2674, 13)
#     id  time  ...  SpringDampRelInert  SpringDampTotalInert
# 0  1.0  0.02  ...           -0.387478             -0.326251
# 1  2.0  0.04  ...           -1.386765             -0.998989
# 2  3.0  0.06  ...           -0.591414              0.796413
# 3  4.0  0.08  ...           -0.591414              0.000453
# 4  5.0  0.10  ...           -1.101254             -0.509387
#
# [5 rows x 13 columns]

# %%
class RungeKuttaIntegratorCell(Layer):
    def __init__(self, m, c, k, dt, initial_state, **kwargs):
        super(RungeKuttaIntegratorCell, self).__init__(**kwargs)
        self.Minv = linalg.inv(np.diag(m))
        self._c   = c
        self.K    = self._getCKmatrix(k)
        self.initial_state = initial_state
        self.state_size    = 2*len(m)
        self.A  = np.array([0., 0.5, 0.5, 1.0], dtype='float32')
        self.B  = np.array([[1/6, 2/6, 2/6, 1/6]], dtype='float32')
        self.dt = dt

    def build(self, input_shape, **kwargs):
        self.kernel = self.add_weight("C", shape = self._c.shape, trainable = True, initializer = lambda shape, dtype: self._c, **kwargs)
        self.built  = True

    def call(self, inputs, states):
        C    = self._getCKmatrix(self.kernel)
        y    = states[0][:,:1]
        ydot = states[0][:,1:]
        print("Shape of the State: ",len(states)," ",len(states[0])," ",len(states[0][0]),"\n")
        print("current C value: ",C)
        
        yddoti = self._fun(self.Minv, self.K, C, inputs, y, ydot)
        yi     = y + self.A[0] * ydot * self.dt
        ydoti  = ydot + self.A[0] * yddoti * self.dt
        fn     = self._fun(self.Minv, self.K, C, inputs, yi, ydoti)
        for j in range(1,4):
            yn    = y + self.A[j] * ydot * self.dt
            ydotn = ydot + self.A[j] * yddoti * self.dt
            ydoti = concat([ydoti, ydotn], axis=0)
            fn    = concat([fn, self._fun(self.Minv, self.K, C, inputs, yn, ydotn)], axis=0)

        y    = y + linalg.matmul(self.B, ydoti) * self.dt
        ydot = ydot + linalg.matmul(self.B, fn) * self.dt
        return y, [concat(([y, ydot]), axis=-1)]

    def _fun(self, Minv, K, C, u, y, ydot):
        return linalg.matmul(u - linalg.matmul(ydot, C, transpose_b=True) - linalg.matmul(y, K, transpose_b=True), Minv, transpose_b=True)
                             
    def _getCKmatrix(self, a):
        return convert_to_tensor([[a[0]]], dtype=float32)

    def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
        return self.initial_state

# %%
a = tf.constant(np.arange(1, 2, dtype=np.int32), shape=[1,1])
print(a)
b = tf.constant(np.arange(5, 6, dtype=np.int32), shape=[1,1])
print(b)
print(linalg.matmul(a,b))
a1=np.arange(1,2,dtype=np.int32).reshape((1,1))
print(a1)
b1=np.arange(5,6,dtype=np.int32).reshape((1,1))
print(b1)
print(tf.constant(a1))
print(tf.constant(np.matmul(a1,b1)))
#print(linalg.inv(np.diag(m)))
# print(linalg.matmul(, C, transpose_b=True))
# Out:
# tf.Tensor([[1]], shape=(1, 1), dtype=int32)
# tf.Tensor([[5]], shape=(1, 1), dtype=int32)
# tf.Tensor([[5]], shape=(1, 1), dtype=int32)
# [[1]]
# [[5]]
# tf.Tensor([[1]], shape=(1, 1), dtype=int32)
# tf.Tensor([[5]], shape=(1, 1), dtype=int32)

# %%
def create_model(m, c, k, dt, initial_state, batch_input_shape, return_sequences = True, unroll = False):
    rkCell = RungeKuttaIntegratorCell(m=m, c=c, k=k, dt=dt, initial_state=initial_state)
    PINN   = RNN(cell=rkCell, batch_input_shape=batch_input_shape, return_sequences=return_sequences, return_state=False, unroll=unroll)
    model  = Sequential()
    model.add(PINN)
    model.compile(loss='mse', optimizer=RMSprop(0.01), metrics=['mae'])
    return model

# %%
 # masses, spring coefficients, and damping coefficients
m = np.array([200/386], dtype='float32')
c = np.array([1], dtype='float32') # initial guess
k = np.array([20.4], dtype='float32')

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# print(df["Force"].head())
# df[["Force"]] = scaler.fit_transform(df[["Force"]])
# print(df["Force"].head())

# %%
# data
# df = pd.read_csv('/content/drive/MyDrive/Major Project/New/Data/Training Datasets/phy/1dof_newbarks - Sheet1.csv')
t  = df[['time']].values
dt = 0.02
utrain = df[['Force']].values[np.newaxis, :, :]*200
ytrain = df[['Displacement']].values[np.newaxis, :, :]*-1
# print(df.describe)

# %%
print(ytrain.shape,utrain.shape)
plt.figure()
plt.plot( utrain[0, :, :], 'r',label='m1')
plt.xlabel('t(sec)')
plt.ylabel('u1')
plt.grid('on')

plt.figure()
plt.plot( ytrain[0, :, :], 'b',label='y1')
plt.xlabel('t(sec)')
plt.ylabel('y1')
plt.grid('on')
# Out:
# (1, 2674, 1) (1, 2674, 1)

# %%
#np.linalg.inv(np.diag(m))

# %%
    # fitting physics-informed neural network
initial_state =np.zeros((1,2 * len(m),), dtype='float32')
model = create_model(m, c, k, dt, initial_state=initial_state, batch_input_shape=utrain.shape)
print(model.summary())
yPred_before = model.predict_on_batch(utrain)[0, :, :]
history = model.fit(utrain, ytrain, epochs=80, steps_per_epoch=1, verbose=1)
yPred   = model.predict_on_batch(utrain)[0, :, :]
# Out:
# Shape of the State:  1   1   2
#
# current C value:  Tensor("rnn_6/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# Shape of the State:  1   1   2
#
# current C value:  Tensor("rnn_6/while/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn_6 (RNN)                  (1, 2674, 1)              1
# =================================================================
# Total params: 1
# Trainable params: 1
# Non-trainable params: 0
# _________________________________________________________________
# None
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential_6/rnn_6/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential_6/rnn_6/while/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# Epoch 1/80
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential_6/rnn_6/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential_6/rnn_6/while/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential_6/rnn_6/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential_6/rnn_6/while/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# 1/1 [==============================] - 3s 3s/step - loss: 0.4234 - mae: 0.4658
# Epoch 2/80
# 1/1 [==============================] - 1s 936ms/step - loss: 0.4167 - mae: 0.4623
# Epoch 3/80
# 1/1 [==============================] - 1s 860ms/step - loss: 0.4115 - mae: 0.4596
# Epoch 4/80
# 1/1 [==============================] - 1s 841ms/step - loss: 0.4070 - mae: 0.4572
# Epoch 5/80
# 1/1 [==============================] - 1s 860ms/step - loss: 0.4028 - mae: 0.4550
# Epoch 6/80
# 1/1 [==============================] - 1s 843ms/step - loss: 0.3988 - mae: 0.4529
# Epoch 7/80
# 1/1 [==============================] - 1s 854ms/step - loss: 0.3949 - mae: 0.4508
# Epoch 8/80
# 1/1 [==============================] - 1s 816ms/step - loss: 0.3912 - mae: 0.4488
# Epoch 9/80
# 1/1 [==============================] - 1s 876ms/step - loss: 0.3875 - mae: 0.4468
# Epoch 10/80
# 1/1 [==============================] - 1s 982ms/step - loss: 0.3838 - mae: 0.4448
# Epoch 11/80
# 1/1 [==============================] - 1s 841ms/step - loss: 0.3801 - mae: 0.4428
# Epoch 12/80
# 1/1 [==============================] - 1s 842ms/step - loss: 0.3764 - mae: 0.4408
# Epoch 13/80
# 1/1 [==============================] - 1s 934ms/step - loss: 0.3727 - mae: 0.4387
# Epoch 14/80
# 1/1 [==============================] - 1s 886ms/step - loss: 0.3690 - mae: 0.4366
# Epoch 15/80
# 1/1 [==============================] - 1s 881ms/step - loss: 0.3652 - mae: 0.4345
# Epoch 16/80
# 1/1 [==============================] - 1s 882ms/step - loss: 0.3614 - mae: 0.4323
# Epoch 17/80
# 1/1 [==============================] - 1s 949ms/step - loss: 0.3576 - mae: 0.4301
# Epoch 18/80
# 1/1 [==============================] - 1s 844ms/step - loss: 0.3537 - mae: 0.4279
# Epoch 19/80
# 1/1 [==============================] - 1s 869ms/step - loss: 0.3497 - mae: 0.4256
# Epoch 20/80
# 1/1 [==============================] - 1s 853ms/step - loss: 0.3457 - mae: 0.4232
# Epoch 21/80
# 1/1 [==============================] - 1s 895ms/step - loss: 0.3415 - mae: 0.4208
# Epoch 22/80
# 1/1 [==============================] - 1s 846ms/step - loss: 0.3373 - mae: 0.4183
# Epoch 23/80
# 1/1 [==============================] - 1s 817ms/step - loss: 0.3331 - mae: 0.4158
# Epoch 24/80
# 1/1 [==============================] - 1s 840ms/step - loss: 0.3287 - mae: 0.4132
# Epoch 25/80
# 1/1 [==============================] - 1s 844ms/step - loss: 0.3242 - mae: 0.4105
# Epoch 26/80
# 1/1 [==============================] - 1s 853ms/step - loss: 0.3196 - mae: 0.4077
# Epoch 27/80
# 1/1 [==============================] - 1s 847ms/step - loss: 0.3150 - mae: 0.4048
# Epoch 28/80
# 1/1 [==============================] - 1s 843ms/step - loss: 0.3102 - mae: 0.4019
# Epoch 29/80
# 1/1 [==============================] - 1s 837ms/step - loss: 0.3053 - mae: 0.3988
# Epoch 30/80
# 1/1 [==============================] - 1s 848ms/step - loss: 0.3002 - mae: 0.3957
# Epoch 31/80
# 1/1 [==============================] - 1s 874ms/step - loss: 0.2951 - mae: 0.3924
# Epoch 32/80
# 1/1 [==============================] - 1s 856ms/step - loss: 0.2898 - mae: 0.3890
# Epoch 33/80
# 1/1 [==============================] - 1s 839ms/step - loss: 0.2844 - mae: 0.3855
# Epoch 34/80
# 1/1 [==============================] - 1s 853ms/step - loss: 0.2788 - mae: 0.3819
# Epoch 35/80
# 1/1 [==============================] - 1s 840ms/step - loss: 0.2730 - mae: 0.3781
# Epoch 36/80
# 1/1 [==============================] - 1s 855ms/step - loss: 0.2671 - mae: 0.3741
# Epoch 37/80
# 1/1 [==============================] - 1s 876ms/step - loss: 0.2611 - mae: 0.3700
# Epoch 38/80
# 1/1 [==============================] - 1s 842ms/step - loss: 0.2548 - mae: 0.3657
# Epoch 39/80
# 1/1 [==============================] - 1s 835ms/step - loss: 0.2484 - mae: 0.3612
# Epoch 40/80
# 1/1 [==============================] - 1s 857ms/step - loss: 0.2418 - mae: 0.3566
# Epoch 41/80
# 1/1 [==============================] - 1s 861ms/step - loss: 0.2350 - mae: 0.3517
# Epoch 42/80
# 1/1 [==============================] - 1s 860ms/step - loss: 0.2279 - mae: 0.3466
# Epoch 43/80
# 1/1 [==============================] - 1s 883ms/step - loss: 0.2207 - mae: 0.3413
# Epoch 44/80
# 1/1 [==============================] - 1s 858ms/step - loss: 0.2133 - mae: 0.3357
# Epoch 45/80
# 1/1 [==============================] - 1s 966ms/step - loss: 0.2056 - mae: 0.3298
# Epoch 46/80
# 1/1 [==============================] - 1s 841ms/step - loss: 0.1976 - mae: 0.3236
# Epoch 47/80
# 1/1 [==============================] - 1s 858ms/step - loss: 0.1895 - mae: 0.3171
# Epoch 48/80
# 1/1 [==============================] - 1s 837ms/step - loss: 0.1810 - mae: 0.3103
# Epoch 49/80
# 1/1 [==============================] - 1s 928ms/step - loss: 0.1723 - mae: 0.3030
# Epoch 50/80
# 1/1 [==============================] - 1s 890ms/step - loss: 0.1634 - mae: 0.2954
# Epoch 51/80
# 1/1 [==============================] - 1s 958ms/step - loss: 0.1542 - mae: 0.2873
# Epoch 52/80
# 1/1 [==============================] - 1s 843ms/step - loss: 0.1447 - mae: 0.2787
# Epoch 53/80
# 1/1 [==============================] - 1s 849ms/step - loss: 0.1350 - mae: 0.2697
# Epoch 54/80
# 1/1 [==============================] - 1s 892ms/step - loss: 0.1250 - mae: 0.2600
# Epoch 55/80
# 1/1 [==============================] - 1s 832ms/step - loss: 0.1148 - mae: 0.2497
# Epoch 56/80
# 1/1 [==============================] - 1s 826ms/step - loss: 0.1045 - mae: 0.2387
# Epoch 57/80
# 1/1 [==============================] - 1s 897ms/step - loss: 0.0939 - mae: 0.2270
# Epoch 58/80
# 1/1 [==============================] - 1s 894ms/step - loss: 0.0833 - mae: 0.2145
# Epoch 59/80
# 1/1 [==============================] - 1s 866ms/step - loss: 0.0727 - mae: 0.2011
# Epoch 60/80
# 1/1 [==============================] - 1s 859ms/step - loss: 0.0622 - mae: 0.1867
# Epoch 61/80
# 1/1 [==============================] - 1s 871ms/step - loss: 0.0520 - mae: 0.1715
# Epoch 62/80
# 1/1 [==============================] - 1s 869ms/step - loss: 0.0422 - mae: 0.1554
# Epoch 63/80
# 1/1 [==============================] - 1s 862ms/step - loss: 0.0330 - mae: 0.1385
# Epoch 64/80
# 1/1 [==============================] - 1s 886ms/step - loss: 0.0248 - mae: 0.1210
# Epoch 65/80
# 1/1 [==============================] - 1s 852ms/step - loss: 0.0178 - mae: 0.1034
# Epoch 66/80
# 1/1 [==============================] - 1s 968ms/step - loss: 0.0121 - mae: 0.0862
# Epoch 67/80
# 1/1 [==============================] - 1s 883ms/step - loss: 0.0080 - mae: 0.0706
# Epoch 68/80
# 1/1 [==============================] - 1s 863ms/step - loss: 0.0053 - mae: 0.0579
# Epoch 69/80
# 1/1 [==============================] - 1s 877ms/step - loss: 0.0038 - mae: 0.0491
# Epoch 70/80
# 1/1 [==============================] - 1s 920ms/step - loss: 0.0031 - mae: 0.0441
# Epoch 71/80
# 1/1 [==============================] - 1s 892ms/step - loss: 0.0028 - mae: 0.0417
# Epoch 72/80
# 1/1 [==============================] - 1s 915ms/step - loss: 0.0027 - mae: 0.0408
# Epoch 73/80
# 1/1 [==============================] - 1s 911ms/step - loss: 0.0027 - mae: 0.0405
# Epoch 74/80
# 1/1 [==============================] - 1s 974ms/step - loss: 0.0027 - mae: 0.0404
# Epoch 75/80
# 1/1 [==============================] - 1s 888ms/step - loss: 0.0027 - mae: 0.0404
# Epoch 76/80
# 1/1 [==============================] - 1s 1000ms/step - loss: 0.0027 - mae: 0.0404
# Epoch 77/80
# 1/1 [==============================] - 1s 865ms/step - loss: 0.0027 - mae: 0.0403
# Epoch 78/80
# 1/1 [==============================] - 1s 947ms/step - loss: 0.0027 - mae: 0.0403
# Epoch 79/80
# 1/1 [==============================] - 1s 909ms/step - loss: 0.0027 - mae: 0.0403
# Epoch 80/80
# 1/1 [==============================] - 1s 836ms/step - loss: 0.0027 - mae: 0.0403

# %%
    # plotting prediction results
plt.plot( ytrain[0, :, :], 'gray',label='target')
plt.plot( yPred_before[:, :], 'r', label='before training')
plt.plot( yPred[:, :], 'b', label='after training')
plt.xlabel('t')
plt.ylabel('y')
plt.grid('on')
plt.legend()
plt.show()

# %%
dt
# Out:
# 0.02

# %%
c
# Out:
# array([1.], dtype=float32)

# %%
print(history.history.keys())
plt.figure()
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper right')
plt.show()
plt.figure()
plt.plot(history.history['mae'])
# plt.plot(history.history['val_loss'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'mae'])

# %%
df = pd.read_csv('/content/drive/MyDrive/Major Project/New/Data/Training Datasets/phy/newbarks_u_02 - Sheet1.csv')
t  = df[['t']].values
dt=0.02
xval = df[['u']].values[np.newaxis, :, :]*(200)
yval = df[['y']].values[np.newaxis, :, :]*-1

ypred=model.predict(xval)
model.evaluate(ypred,yval)
# Out:
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential_6/rnn_6/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential_6/rnn_6/while/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential_6/rnn_6/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# Shape of the State:  1   1   2
#
# current C value:  Tensor("sequential_6/rnn_6/while/runge_kutta_integrator_cell_6/packed:0", shape=(1, 1), dtype=float32)
# 1/1 [==============================] - 0s 489ms/step - loss: 0.9376 - mae: 0.7161
# [0.9375894665718079, 0.7161403894424438]

# %%
plt.figure()
plt.plot( xval[0, :, :], 'r',label='m1')
plt.xlabel('t(sec)')
plt.ylabel('u1')
plt.grid('on')

plt.figure()
plt.plot( yval[0, :, :], 'b',label='y1')
plt.xlabel('t(sec)')
plt.ylabel('y1')
plt.grid('on')

# %%
plt.plot( yval[0, :, :], 'r',label='true')
plt.plot( ypred[0,:, :], 'b', label='after training')
plt.xlabel('t')
plt.ylabel('y')
plt.grid('on')
plt.legend()
plt.show()

# %%
print(model.layers[0].get_weights()[0])
# Out:
# [0.13286348]
